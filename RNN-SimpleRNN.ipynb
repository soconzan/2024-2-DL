# %% [markdown]
# ### 데이터 준비

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# 데이터 생성
dates = pd.date_range('20210101', periods=100)
data = np.sin(np.linspace(0, 100, 100))

# df 변환
df = pd.DataFrame(data, index=dates, columns=['Value'])

# 데이터 시각화
plt.plot(df)
plt.title("Generated Time Series Data")
plt.show()

# %% [markdown]
# ### 데이터 전처리

# %%
from sklearn.preprocessing import MinMaxScaler

# 데이터 스케일링
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(df)

# 시퀀스 데이터 생성
def create_sequences(data, sequence_length):
    X = []
    y = []
    for i in range(len(data) - sequence_length):
        X.append(data[i:i + sequence_length, 0])
        y.append(data[i + sequence_length, 0])
    return np.array(X), np.array(y)

sequence_length = 10
X, y = create_sequences(scaled_data, sequence_length)

# RNN 데이터 형식으로 변환
X = X.reshape((X.shape[0], X.shape[1], 1))

# 학습 및 테스트 세트 분리
split = int(len(X) * 0.8)
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# %% [markdown]
# ### RNN 모델 설계

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense

# RNN 모델
model = Sequential()
model.add(SimpleRNN(50, activation='tanh', input_shape=(sequence_length, 1)))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mse')

model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)               │ (None, 50)                  │           2,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │              51 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,651 (10.36 KB)
#  Trainable params: 2,651 (10.36 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### 모델 학습

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

history = model.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test),
                    batch_size=16, callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.6267 - val_loss: 0.2112
# Epoch 2/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1680 - val_loss: 0.1021
# Epoch 3/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0742 - val_loss: 0.0053
# Epoch 4/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0119 - val_loss: 0.0303
# Epoch 5/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0221 - val_loss: 0.0088
# Epoch 6/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0119 - val_loss: 0.0112
# Epoch 7/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0078 - val_loss: 0.0011
# Epoch 8/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0023 - val_loss: 0.0039
# Epoch 9/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0035 - val_loss: 0.0015
# Epoch 10/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 11/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0014 - val_loss: 4.2834e-04
# Epoch 12/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.4633e-04 - val_loss: 7.5290e-04
# Epoch 13/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.8363e-04 - val_loss: 5.5195e-04
# Epoch 14/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.2789e-04 - val_loss: 4.4975e-04
# Epoch 15/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.7203e-04 - val_loss: 3.8405e-04
# Epoch 16/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.6620e-04 - val_loss: 3.2754e-04
# Epoch 17/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.9044e-04 - val_loss: 3.3621e-04
# Epoch 18/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.2789e-04 - val_loss: 2.8199e-04
# Epoch 19/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.6674e-04 - val_loss: 2.7848e-04
# Epoch 20/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.6952e-04 - val_loss: 2.7061e-04
# Epoch 21/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.3463e-04 - val_loss: 2.4681e-04
# Epoch 22/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.3186e-04 - val_loss: 2.4440e-04
# Epoch 23/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.4081e-04 - val_loss: 2.3597e-04
# Epoch 24/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.3152e-04 - val_loss: 2.1528e-04
# Epoch 25/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.8002e-04 - val_loss: 2.0574e-04
# Epoch 26/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7673e-04 - val_loss: 1.9159e-04
# Epoch 27/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7083e-04 - val_loss: 1.8545e-04
# Epoch 28/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6345e-04 - val_loss: 1.7277e-04
# Epoch 29/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.6577e-04 - val_loss: 1.6152e-04
# Epoch 30/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.5399e-04 - val_loss: 1.5597e-04
# Epoch 31/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.5938e-04 - val_loss: 1.5049e-04
# Epoch 32/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3969e-04 - val_loss: 1.4036e-04
# Epoch 33/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2293e-04 - val_loss: 1.3548e-04
# Epoch 34/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2663e-04 - val_loss: 1.2540e-04
# Epoch 35/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0866e-04 - val_loss: 1.1906e-04
# Epoch 36/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.0513e-04 - val_loss: 1.1285e-04
# Epoch 37/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1399e-04 - val_loss: 1.0610e-04
# Epoch 38/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0175e-04 - val_loss: 1.0486e-04
# Epoch 39/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.2166e-05 - val_loss: 9.6719e-05
# Epoch 40/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.8965e-05 - val_loss: 9.1998e-05
# Epoch 41/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.3325e-05 - val_loss: 8.7457e-05
# Epoch 42/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.5118e-05 - val_loss: 8.6839e-05
# Epoch 43/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.9635e-05 - val_loss: 7.8546e-05
# Epoch 44/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.9071e-05 - val_loss: 7.3375e-05
# Epoch 45/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.3950e-05 - val_loss: 6.9904e-05
# Epoch 46/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.8270e-05 - val_loss: 6.7764e-05
# Epoch 47/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.6194e-05 - val_loss: 6.2359e-05
# Epoch 48/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.3944e-05 - val_loss: 6.5248e-05
# Epoch 49/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.7074e-05 - val_loss: 5.8170e-05
# Epoch 50/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.4707e-05 - val_loss: 5.4620e-05

# %%
# 학습 시각화
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %% [markdown]
# ### 예측 결과

# %%
# 테스트 데이터 예측
y_pred = model.predict(X_test)

# 실제 값과 예측 값의 스케일을 다시 복원
y_test_scaled = scaler.inverse_transform(y_test.reshape(-1, 1))
y_pred_scaled = scaler.inverse_transform(y_pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step

# %%
# 결과 시각화
plt.plot(y_test_scaled, label='Actual')
plt.plot(y_pred_scaled, label='Predicted')
plt.title('Actual vs Predicted')
plt.legend()
plt.show()

# %%
from sklearn.metrics import r2_score

y_pred = model.predict(X_test)

y_test_scaled = scaler.inverse_transform(y_test.reshape(-1, 1))
y_pred_scaled = scaler.inverse_transform(y_pred)

r2 = r2_score(y_test_scaled, y_pred_scaled)
print(f'결정계수 (R²): {r2:.4f}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 결정계수 (R²): 0.9996
